# %%
import pandas as pd
import numpy as np
# Загружаем файл
file_path = "dt.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#                                           Название  \
# 0                                  Сетевой инженер
# 1  Специалист по антитеррористической защищенности
# 2                                 Специалист по IT
# 3                               Разработчик Python
# 4                  Инженер UNIX/SAN-инфраструктуры
#
#                      Компания  \
# 0                   Турболинк
# 1  Киностудия им. М. Горького
# 2                    Торгпром
# 3                    SberTech
# 4                 NGRServices
#
#                                           Требования  \
# 0  Глубокие знания сетевых технологий (стек TCP/I...
# 1  Опыт работы на релевантной позиции от 2-х лет....
# 2  Владение языками программирования: C++ / SQL /...
# 3  Опыт разработки на Python от 3-х лет (ООП и па...
# 4  Глубокие знания и минимум 5 лет опыта в админи...
#
#                                           Обязаности              Зарплата  \
# 0  Администрирование сетевого оборудования (инста...   350000 - 400000 RUR
# 1  Организовывать работы по обеспечению антитерро...            Не указана
# 2                                                NaN  300000 - 2500000 RUR
# 3  Разрабатывать продуктовые сервисы и автоматизи...            Не указана
# 4  Администрирование серверов на базе Linux и соп...            Не указана
#
#           Опыт работы                           Ссылка
# 0       От 3 до 6 лет  https://hh.ru/vacancy/118439765
# 1  От 1 года до 3 лет  https://hh.ru/vacancy/118467981
# 2  От 1 года до 3 лет  https://hh.ru/vacancy/118279002
# 3  От 1 года до 3 лет  https://hh.ru/vacancy/118226958
# 4         Более 6 лет  https://hh.ru/vacancy/117562577

# %%
import pandas as pd
import numpy as np
import re

# Курсы валют
exchange_rates = {
    "$": 92.5,   # 1 доллар = 92.5 руб.
    "€": 100.2,  # 1 евро = 100.2 руб.
    "₽": 1       # Рубли остаются без изменений
}

# Функция для обработки зарплаты (извлечение чисел и перевод валют)
def parse_salary(salary):
    if pd.isna(salary) or "Не указана" in str(salary):
        return np.nan
    
    salary = salary.replace(" ", "")  # Убираем пробелы
    match = re.match(r"([\$\€₽]?)(\d+)-?(\d+)?", salary)  # Ищем валюту и числа
    if not match:
        return np.nan

    currency, min_val, max_val = match.groups()
    min_val = int(min_val)
    max_val = int(max_val) if max_val else min_val  # Если одно число, берем его же
    avg_salary = (min_val + max_val) / 2  # Среднее значение

    return avg_salary * exchange_rates.get(currency, 1)  # Конвертируем в рубли

# Функция для форматирования зарплаты (100000 → 100K)
def format_salary(value):
    if pd.isna(value):
        return np.nan
    if value >= 1000:
        return int(value // 1000)
    return str(value)

# Функция для обработки опыта работы
def parse_experience(exp):
    if pd.isna(exp):
        return np.nan
    exp = str(exp)
    if "Более 6 лет" in exp:
        return 7
    if "От 3 до 6 лет" in exp:
        return 4.5
    if "От 1 года до 3 лет" in exp:
        return 2
    if "Нет опыта" in exp:
        return 0
    return np.nan

# Загружаем файл
file_path = "dt.csv"
df = pd.read_csv(file_path)

# Обрабатываем зарплату
df["Зарплата"] = df["Зарплата"].apply(parse_salary)
df["Зарплата"] = df["Зарплата"].apply(format_salary)

# Обрабатываем опыт работы
df["Опыт работы"] = df["Опыт работы"].apply(parse_experience)

# Выводим результат
print(df[["Зарплата", "Опыт работы"]].head())

# Выведем первые строки после обработки
# Out:
#   Зарплата  Опыт работы
# 0      375          4.5
# 1      NaN          2.0
# 2     1400          2.0
# 3      NaN          2.0
# 4      NaN          7.0

# %%
df
# Out:
#                                                Название  \
# 0                                       Сетевой инженер
# 1       Специалист по антитеррористической защищенности
# 2                                      Специалист по IT
# 3                                    Разработчик Python
# 4                       Инженер UNIX/SAN-инфраструктуры
# ...                                                 ...
# 1995                            Инженер DevOps / ДевОпс
# 1996                                       Инженер SIEM
# 1997  Application Security Engineer (безопасность пр...
# 1998  Архитектор систем ИБ (аутентификация и биометрия)
# 1999                 Стажер в пресейл ИТ-инфраструктуры
#
#                         Компания  \
# 0                      Турболинк
# 1     Киностудия им. М. Горького
# 2                       Торгпром
# 3                       SberTech
# 4                    NGRServices
# ...                          ...
# 1995                    MLM Soft
# 1996               ГКУ Инфогород
# 1997   ПСБ (ПАО «Промсвязьбанк»)
# 1998            Инфосистемы Джет
# 1999    iCore (Integration Core)
#
#                                              Требования  \
# 0     Глубокие знания сетевых технологий (стек TCP/I...
# 1     Опыт работы на релевантной позиции от 2-х лет....
# 2     Владение языками программирования: C++ / SQL /...
# 3     Опыт разработки на Python от 3-х лет (ООП и па...
# 4     Глубокие знания и минимум 5 лет опыта в админи...
# ...                                                 ...
# 1995  Linux (Ubuntu/Debian). Контейнеризация kuberne...
# 1996  Высшее образование по направлению ИБ. Опыт раб...
# 1997  Понимание архитектуры построения современной w...
# 1998                    Опыт работы в сфере IT от 5 лет
# 1999  Техническое образование или его получение в пр...
#
#                                              Обязаности Зарплата  Опыт работы  \
# 0     Администрирование сетевого оборудования (инста...      375          4.5
# 1     Организовывать работы по обеспечению антитерро...      NaN          2.0
# 2                                                   NaN     1400          2.0
# 3     Разрабатывать продуктовые сервисы и автоматизи...      NaN          2.0
# 4     Администрирование серверов на базе Linux и соп...      NaN          7.0
# ...                                                 ...      ...          ...
# 1995  Обеспечение DevOps инфраструктуры и автоматиза...      200          7.0
# 1996  Администрировfnm СЗИ: MaxPatrol SIEM, Security...      NaN          2.0
# 1997  Участие в проектах по обеспечению ИБ во внедря...      NaN          2.0
# 1998  Выявление и согласование требований к Системе....      NaN          7.0
# 1999  Идентификация потребностей клиентов: встречи с...      NaN          0.0
#
#                                Ссылка
# 0     https://hh.ru/vacancy/118439765
# 1     https://hh.ru/vacancy/118467981
# 2     https://hh.ru/vacancy/118279002
# 3     https://hh.ru/vacancy/118226958
# 4     https://hh.ru/vacancy/117562577
# ...                               ...
# 1995  https://hh.ru/vacancy/117380958
# 1996  https://hh.ru/vacancy/118277989
# 1997   https://hh.ru/vacancy/86043215
# 1998  https://hh.ru/vacancy/108195525
# 1999  https://hh.ru/vacancy/116084905
#
# [2000 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Убираем строки с пропущенными значениями
df_ed = df[df['Требования'].str.contains('Высшее образование', na=False)]
df_wed = df[~df['Требования'].str.contains('Высшее образование', na=False)]

df_ed.head()
# Out:
#                                   Название  \
# 22  Инженер по информационной безопасности
# 23             Техник по защите информации
# 24            Дата-инженер / Data-engineer
# 35         Специалист по защите информации
# 39         Системный администратор Windows
#
#                                       Компания  \
# 22                                       Xello
# 23  Останкино, Телевизионный технический центр
# 24                                 Kuppersberg
# 35                        ФГБУ НИЦИ МИД России
# 39                                      ФИНТЕХ
#
#                                            Требования  \
# 22  Опыт установки и администрирования серверных О...
# 23  Высшее образование (сфера ИБ). Практический оп...
# 24  Высшее образование. Желательно дополнительное ...
# 35  Высшее образование по профилю ИТ или ИБ. Опыт ...
# 39  Высшее образование в области информационных те...
#
#                                            Обязаности Зарплата  Опыт работы  \
# 22  Управление техническими аспектами продукта ком...      NaN          0.0
# 23  Администрирование средств защиты информации (D...      190          0.0
# 24  Интеграция данных в DWH при помощи Python/API ...      230          4.5
# 35  Мониторинг и анализ событий информационной без...      150          2.0
# 39  Федеральный центр обработки данных Пограничной...      140          4.5
#
#                              Ссылка
# 22  https://hh.ru/vacancy/118251741
# 23  https://hh.ru/vacancy/118283497
# 24  https://hh.ru/vacancy/118342268
# 35  https://hh.ru/vacancy/118105784
# 39  https://hh.ru/vacancy/117412330

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
df_with_higher_edu = df_ed
df_without_higher_edu = df_wed
# Предположим, что df_with_higher_edu и df_without_higher_edu уже созданы
n = range(len(df_with_higher_edu))  # Индексы строк
n2 = range(len(df_without_higher_edu))  

plt.scatter(n, df_with_higher_edu["Зарплата"], label="С высшим образованием", color="green",alpha=0.6)
plt.scatter(n2, df_without_higher_edu["Зарплата"], label="Без высшего образования", color="orange", alpha=0.6)

# Добавление подписей и легенды
plt.xlabel("Группы")
plt.ylabel("Зарплата в тысячах")
plt.legend()
plt.title("Сравнение зарплат")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# Проверим тип данных в зарплате
print(df_with_higher_edu.dtypes)
print(df_without_higher_edu.dtypes)

# Преобразуем зарплату в числовой формат, если нужно
df_with_higher_edu["Зарплата"] = pd.to_numeric(df_with_higher_edu["Зарплата"], errors='coerce')
df_without_higher_edu["Зарплата"] = pd.to_numeric(df_without_higher_edu["Зарплата"], errors='coerce')

# Заполним пропущенные значения средним значением
df_with_higher_edu["Зарплата"].fillna(df_with_higher_edu["Зарплата"].mean(), inplace=True)
df_without_higher_edu["Зарплата"].fillna(df_without_higher_edu["Зарплата"].mean(), inplace=True)

# Добавляем метки классов
df_with_higher_edu["Высшее_образование"] = 1
df_without_higher_edu["Высшее_образование"] = 0

# Определяем признаки и целевую переменную
X1 = df_with_higher_edu[["Опыт работы"]]
y1 = df_with_higher_edu["Зарплата"]
X2 = df_without_higher_edu[["Опыт работы"]]
y2 = df_without_higher_edu["Зарплата"]

# Разбиваем на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.15, random_state=42)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X1, y1, test_size=0.15, random_state=42)

# Обучаем модель для людей без высшего образования
clf = DecisionTreeRegressor(random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# Обучаем модель для людей с высшим образованием
clf2 = DecisionTreeRegressor(random_state=42)
clf2.fit(X_train2, y_train2)
y_pred2 = clf2.predict(X_test2)

# Создаем DataFrame с тестовыми данными и предсказаниями

# Визуализация данных
plt.scatter(df_without_higher_edu["Опыт работы"], df_without_higher_edu["Зарплата"], 
            label="Без высшего образования", color="green", alpha=0.6)
plt.scatter(df_with_higher_edu["Опыт работы"], df_with_higher_edu["Зарплата"], 
            label="С высшим образованием", color="red", alpha=0.6)
plt.scatter(X_test, y_pred, color="blue", alpha=0.6, label="Прогноз без ВО")
plt.scatter(X_test2, y_pred2, color="yellow", alpha=0.6, label="Прогноз с ВО")

plt.xlabel("Опыт работы")
plt.ylabel("Зарплата")
plt.legend()
plt.show()
# Out:
# Название        object
# Компания        object
# Требования      object
# Обязаности      object
# Зарплата        object
# Опыт работы    float64
# Ссылка          object
# dtype: object
# Название        object
# Компания        object
# Требования      object
# Обязаности      object
# Зарплата        object
# Опыт работы    float64
# Ссылка          object
# dtype: object
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_higher_edu["Зарплата"] = pd.to_numeric(df_with_higher_edu["Зарплата"], errors='coerce')
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_higher_edu["Зарплата"] = pd.to_numeric(df_without_higher_edu["Зарплата"], errors='coerce')
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_with_higher_edu["Зарплата"].fillna(df_with_higher_edu["Зарплата"].mean(), inplace=True)
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_higher_edu["Зарплата"].fillna(df_with_higher_edu["Зарплата"].mean(), inplace=True)
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_without_higher_edu["Зарплата"].fillna(df_without_higher_edu["Зарплата"].mean(), inplace=True)
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_higher_edu["Зарплата"].fillna(df_without_higher_edu["Зарплата"].mean(), inplace=True)
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_higher_edu["Высшее_образование"] = 1
# C:\Users\adm\AppData\Local\Temp\ipykernel_29328\2001467563.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_higher_edu["Высшее_образование"] = 0

# %%
plt.scatter(X_test,y_pred ,color = "blue", alpha=0.6)
plt.scatter(X_test2,y_pred2 ,color = "yellow", alpha=0.6)
